# %%
# load env variable oai_key
import os
from dotenv import load_dotenv
from openai import OpenAI
import pandas as pd

load_dotenv()
oai_key = os.getenv("OAI_KEY")

# %%
os.getcwd()
# Out:
# '/Users/elsecaller/Documents/WORK/kings/Policy_Instruments_Paper/Code'

# %%
df = pd.read_csv('../gsp_7_nodes.csv', index_col=0)

df.head(20)
# Out:
#                                                  name entity_type  \
# 1                     groundwater_sustainability_plan         ORG
# 2                                aliso_water_district         ORG
# 3                                            subbasin         GPE
# 4   aliso_water_district_groundwater_sustainabilit...         ORG
# 5              sustainable_groundwater_management_act         ORG
# 6                       department_of_water_resources         ORG
# 7                                   san_joaquin_river         ORG
# 8               groundwater_sustainability_plan_group         ORG
# 9                              coordination_committee         ORG
# 10                                              party         ORG
# 11                             data_management_system         ORG
# 12                                         department         ORG
# 13                                        san_joaquin         GPE
# ...
